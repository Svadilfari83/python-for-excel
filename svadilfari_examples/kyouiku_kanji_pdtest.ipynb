# %%
import pandas as pd
from numpy import nan

# %% [markdown]
# ## File einlesen und info

# %%
# File einlesen, 
# ursprünglich von https://en.wikipedia.org/wiki/Ky%C5%8Diku_kanji
df = pd.read_excel("kyouiku_kanji.xlsx", sheet_name="kyouiku kanji", na_filter=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4273 entries, 0 to 4272
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   #                2136 non-null   float64
#  1   New (Shinjitai)  2136 non-null   object
#  2   Old (Kyūjitai)   367 non-null    object
#  3   Radical          2138 non-null   object
#  4   Strokes          2136 non-null   float64
#  5   Grade            2136 non-null   object
#  6   Year added       291 non-null    float64
#  7   English meaning  2136 non-null   object
#  8   Readings         4272 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 300.6+ KB

# %% [markdown]
# ## filter lines mit kanji
# https://kanokidotorg.github.io/2022/02/16/How-to-filter-out-the-NaN-values-in-a-pandas-dataframe/

# %%
#filter 
ft = df["#"].notna()
df = df.loc[ft, ].set_index("#")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/arno/Coding/python-for-excel/svadilfari_examples/kyouiku_kanji_pdtest.ipynb Cell 6' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/arno/Coding/python-for-excel/svadilfari_examples/kyouiku_kanji_pdtest.ipynb#ch0000005?line=0'>1</a> #filter
# ----> <a href='vscode-notebook-cell:/Users/arno/Coding/python-for-excel/svadilfari_examples/kyouiku_kanji_pdtest.ipynb#ch0000005?line=1'>2</a> ft = df["#"].notna()
#       <a href='vscode-notebook-cell:/Users/arno/Coding/python-for-excel/svadilfari_examples/kyouiku_kanji_pdtest.ipynb#ch0000005?line=2'>3</a> df = df.loc[ft, ].set_index("#")
#
# NameError: name 'df' is not defined

# %%
df = df.rename(columns={"New (Shinjitai)" : "shinjitai", "Old (Kyūjitai)" : "kyuujitai", "Radical" : "radical", "Strokes" : "strokes", "Grade" : "grade" , "Year added": "year", "English meaning" : "meaning", "Readings"  : "readings"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 2136 entries, 1.0 to 2132.0
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shinjitai  2136 non-null   object
#  1   kyuujitai  365 non-null    object
#  2   radical    2136 non-null   object
#  3   strokes    2136 non-null   float64
#  4   grade      2136 non-null   object
#  5   year       291 non-null    float64
#  6   meaning    2136 non-null   object
#  7   readings   2136 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 150.2+ KB

# %%
## Filter getestefe
tf = (df["strokes"] <= 3) | (df["grade"] == "5") 
df.loc[tf, :]
# Out:
#        shinjitai kyuujitai radical  strokes grade    year  \
# #
# 41.0           一       NaN       一      1.0     1     NaN
# 124.0          乙       NaN       乙      1.0     S     NaN
# 131.0          下       NaN       一      3.0     1     NaN
# 247.0          干       NaN       干      3.0     6     NaN
# 292.0          丸       NaN       丶      3.0     2     NaN
# 359.0          九       NaN       乙      2.0     1     NaN
# 360.0          久       NaN       丿      3.0     5     NaN
# 361.0          及       NaN       又      3.0     S     NaN
# 362.0          弓       NaN       弓      3.0     2     NaN
# 557.0          己       NaN       己      3.0     6     NaN
# 587.0          口       NaN       口      3.0     1     NaN
# 588.0          工       NaN       工      3.0     2     NaN
# 693.0          才       NaN       手      3.0     2     NaN
# 744.0          三       NaN       一      3.0     1     NaN
# 745.0          山       NaN       山      3.0     1     NaN
# ...
