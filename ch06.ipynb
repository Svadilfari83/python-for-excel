# %% [markdown]
# # Time Series
# ## DatetimeIndex

# %%
# Let's start by importing the packages we use in this chapter
# and by setting the plotting backend to Plotly
import pandas as pd
import numpy as np
pd.options.plotting.backend = "plotly"

# %%
# This creates a DatetimeIndex based on a start timestamp,
# number of periods and frequency ("D" = daily).
daily_index = pd.date_range("2020-1-1", periods=5, freq="d")
daily_index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
# This creates a DatetimeIndex based on start/end timestamp.
# The frequency is set to "weekly on Sundays" ("W-SUN").
weekly_index = pd.date_range("2022-05-15", "2022-07-30", freq="W-SUN")
weekly_index
# Out:
# DatetimeIndex(['2022-05-15', '2022-05-22', '2022-05-29', '2022-06-05',
#                '2022-06-12', '2022-06-19', '2022-06-26', '2022-07-03',
#                '2022-07-10', '2022-07-17', '2022-07-24'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
# Construct a DataFrame based on the weekly_index. This could be
# the visitor count of a museum that only opens on Sundays.
df_ = pd.DataFrame(data=[21, 15,12,34,45,34,56, 33, 45,45,34],
             columns=["visitors"], index=weekly_index)
df_
# Out:
#             visitors
# 2022-05-15        21
# 2022-05-22        15
# 2022-05-29        12
# 2022-06-05        34
# 2022-06-12        45
# 2022-06-19        34
# 2022-06-26        56
# 2022-07-03        33
# 2022-07-10        45
# 2022-07-17        45
# 2022-07-24        34

# %%
## Arno Selbstversuch
data = [34,499,234,294,293, 294, 244,444,423,5,135, 234]
weekly_index = pd.date_range("2022-05-15", periods=len(data))
_df = pd.DataFrame(data=data, index= weekly_index)
_df.plot.bar(width=720, height= 320)

# %%
msft = pd.read_csv("csv/MSFT.csv")

# %%
msft.sample(3)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 5052  2006-03-22  27.080000  27.500000  26.799999  27.150000  19.896133
# 6946  2013-09-30  33.000000  33.310001  32.700001  33.279999  28.703634
# 591   1988-07-14   0.463542   0.465278   0.458333   0.465278   0.297696
#
#          Volume
# 5052  145696100
# 6946   39839500
# 591    34848000

# %%
msft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8622 entries, 0 to 8621
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8622 non-null   object
#  1   Open       8622 non-null   float64
#  2   High       8622 non-null   float64
#  3   Low        8622 non-null   float64
#  4   Close      8622 non-null   float64
#  5   Adj Close  8622 non-null   float64
#  6   Volume     8622 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 471.6+ KB

# %%
msft.loc[:, "Date"] = pd.to_datetime(msft["Date"])

# %%
msft["Date"]= pd.to_datetime(msft["Date"])

# %%
msft.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
msft = pd.read_csv("csv/MSFT.csv",
                   index_col="Date", parse_dates=["Date"])

# %%
msft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8622 entries, 1986-03-13 to 2020-05-27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       8622 non-null   float64
#  1   High       8622 non-null   float64
#  2   Low        8622 non-null   float64
#  3   Close      8622 non-null   float64
#  4   Adj Close  8622 non-null   float64
#  5   Volume     8622 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 471.5 KB

# %%
msft.loc[:, "Volume"] = msft["Volume"].astype("float")
msft["Volume"].dtype
# Out:
# dtype('float64')

# %%
msft = msft.sort_index()

# %%
msft.index.date
# Out:
# array([datetime.date(1986, 3, 13), datetime.date(1986, 3, 14),
#        datetime.date(1986, 3, 17), ..., datetime.date(2020, 5, 22),
#        datetime.date(2020, 5, 26), datetime.date(2020, 5, 27)],
#       dtype=object)

# %%
msft.loc["2019", "Adj Close"]
# Out:
# Date
# 2019-01-02     99.099190
# 2019-01-03     95.453529
# 2019-01-04     99.893005
# 2019-01-07    100.020401
# 2019-01-08    100.745613
#                  ...
# 2019-12-24    156.515396
# 2019-12-26    157.798309
# 2019-12-27    158.086731
# 2019-12-30    156.724243
# 2019-12-31    156.833633
# Name: Adj Close, Length: 252, dtype: float64

# %%
msft.loc["2019-06":"2020-05", "Adj Close"].plot()

# %% [markdown]
# ## Working with Time Zones

# %%
# Add the time information to the date
msft_close = msft.loc[:, ["Adj Close"]].copy()
msft_close.index = msft_close.index + pd.DateOffset(hours=16)
msft_close.head(2)
# Out:
#                      Adj Close
# Date
# 1986-03-13 16:00:00   0.062205
# 1986-03-14 16:00:00   0.064427

# %%
# Make the timestamps time-zone-aware
msft_close = msft_close.tz_localize("America/New_York")
msft_close.head(2)
# Out:
#                            Adj Close
# Date
# 1986-03-13 16:00:00-05:00   0.062205
# 1986-03-14 16:00:00-05:00   0.064427

# %%
msft_close = msft_close.tz_convert("UTC")
msft_close.loc["2020-01-02", "Adj Close"]  # 21:00 without DST
# Out:
# Date
# 2020-01-02 21:00:00+00:00    159.737595
# Name: Adj Close, dtype: float64

# %%
msft_close.loc["2020-05-01", "Adj Close"]  # 20:00 with DST
# Out:
# Date
# 2020-05-01 20:00:00+00:00    174.085175
# Name: Adj Close, dtype: float64

# %% [markdown]
# ## Shifting and Percentage Changes

# %%
msft_close.head()
# Out:
#                            Adj Close
# Date
# 1986-03-13 21:00:00+00:00   0.062205
# 1986-03-14 21:00:00+00:00   0.064427
# 1986-03-17 21:00:00+00:00   0.065537
# 1986-03-18 21:00:00+00:00   0.063871
# 1986-03-19 21:00:00+00:00   0.062760

# %%
msft_close.shift(1).head()
# Out:
#                            Adj Close
# Date
# 1986-03-13 21:00:00+00:00        NaN
# 1986-03-14 21:00:00+00:00   0.062205
# 1986-03-17 21:00:00+00:00   0.064427
# 1986-03-18 21:00:00+00:00   0.065537
# 1986-03-19 21:00:00+00:00   0.063871

# %%
returns = np.log(msft_close / msft_close.shift(1))
returns = returns.rename(columns={"Adj Close": "returns"})
returns.head()
# Out:
#                             returns
# Date
# 1986-03-13 21:00:00+00:00       NaN
# 1986-03-14 21:00:00+00:00  0.035097
# 1986-03-17 21:00:00+00:00  0.017082
# 1986-03-18 21:00:00+00:00 -0.025749
# 1986-03-19 21:00:00+00:00 -0.017547

# %%
# Plot a histogram with the daily log returns
returns.plot.hist()

# %%
simple_rets = msft_close.pct_change()
simple_rets = simple_rets.rename(columns={"Adj Close": "simple rets"})
simple_rets.head()
# Out:
#                            simple rets
# Date
# 1986-03-13 21:00:00+00:00          NaN
# 1986-03-14 21:00:00+00:00     0.035721
# 1986-03-17 21:00:00+00:00     0.017229
# 1986-03-18 21:00:00+00:00    -0.025421
# 1986-03-19 21:00:00+00:00    -0.017394

# %% [markdown]
# ## Rebasing and Correlation

# %%
parts = []  # List to collect individual DataFrames
for ticker in ["AAPL", "AMZN", "GOOGL", "MSFT"]:
    # "usecols" allows us to only read in the Date and Adj Close
    # For a refresher about f-strings, see Chapter 3
    adj_close = pd.read_csv(f"csv/{ticker}.csv",
                            index_col="Date", parse_dates=["Date"],
                            usecols=["Date", "Adj Close"])
    # Rename the column into the ticker symbol
    # (If you type this example by hand, make sure to keep the
    # following lines correctly indented!)
    adj_close = adj_close.rename(columns={"Adj Close": ticker})
    # Append the stock's DataFrame to the parts list
    parts.append(adj_close)

# %%
# Combine the 4 DataFrames into a single DataFrame
adj_close = pd.concat(parts, axis=1)
adj_close
# Out:
#                   AAPL         AMZN        GOOGL        MSFT
# Date
# 1980-12-12    0.405683          NaN          NaN         NaN
# 1980-12-15    0.384517          NaN          NaN         NaN
# 1980-12-16    0.356296          NaN          NaN         NaN
# 1980-12-17    0.365115          NaN          NaN         NaN
# 1980-12-18    0.375698          NaN          NaN         NaN
# ...                ...          ...          ...         ...
# 2020-05-22  318.890015  2436.879883  1413.239990  183.509995
# 2020-05-26  316.730011  2421.860107  1421.369995  181.570007
# 2020-05-27  318.109985  2410.389893  1420.280029  181.809998
# 2020-05-28  318.250000  2401.100098  1418.239990         NaN
# 2020-05-29  317.940002  2442.370117  1433.520020         NaN
#
# [9950 rows x 4 columns]

# %%
adj_close = adj_close.dropna()
adj_close#.info()
# Out:
#                   AAPL         AMZN        GOOGL        MSFT
# Date
# 2004-08-19    1.898969    38.630001    50.220219   17.505459
# 2004-08-20    1.904534    39.509998    54.209209   17.557100
# 2004-08-23    1.921849    39.450001    54.754753   17.634779
# 2004-08-24    1.975645    39.049999    52.487488   17.634779
# 2004-08-25    2.043664    40.299999    53.053055   17.835468
# ...                ...          ...          ...         ...
# 2020-05-20  319.230011  2497.939941  1409.160034  185.660004
# 2020-05-21  316.850006  2446.739990  1406.750000  183.429993
# 2020-05-22  318.890015  2436.879883  1413.239990  183.509995
# 2020-05-26  316.730011  2421.860107  1421.369995  181.570007
# 2020-05-27  318.109985  2410.389893  1420.280029  181.809998
#
# [3970 rows x 4 columns]

# %%
# Beispiel Arno
_adj_close_rebased = adj_close / adj_close.iloc[0,:] * 100
_adj_close_rebased
# Out:
#                     AAPL         AMZN        GOOGL         MSFT
# Date
# 2004-08-19    100.000000   100.000000   100.000000   100.000000
# 2004-08-20    100.293054   102.278014   107.942996   100.294999
# 2004-08-23    101.204864   102.122703   109.029300   100.738741
# 2004-08-24    104.037770   101.087233   104.514654   100.738741
# 2004-08-25    107.619661   104.323060   105.640828   101.885178
# ...                  ...          ...          ...          ...
# 2020-05-20  16810.701544  6466.321192  2805.961547  1060.583467
# 2020-05-21  16685.370114  6333.781845  2801.162615  1047.844521
# 2020-05-22  16792.797302  6308.257365  2814.085677  1048.301533
# 2020-05-26  16679.051159  6269.376247  2830.274386  1037.219344
# 2020-05-27  16751.720802  6239.683745  2828.104013  1038.590293
#
# [3970 rows x 4 columns]

# %%
_adj_close_rebased.plot()

# %%
# Use a sample from June 2019 - May 2020
adj_close_sample = adj_close.loc["2019-06":"2020-05", :]
rebased_prices = adj_close_sample / adj_close_sample.iloc[0, :] * 100
rebased_prices.head(2)
# Out:
#                   AAPL        AMZN      GOOGL        MSFT
# Date
# 2019-06-03  100.000000  100.000000  100.00000  100.000000
# 2019-06-04  103.658406  102.178197  101.51626  102.770372

# %%
rebased_prices.plot()

# %%
# Correlation of daily log returns
returns = np.log(adj_close / adj_close.shift(1))
returns.corr()
# Out:
#            AAPL      AMZN     GOOGL      MSFT
# AAPL   1.000000  0.424910  0.503497  0.486065
# AMZN   0.424910  1.000000  0.486690  0.485725
# GOOGL  0.503497  0.486690  1.000000  0.525645
# MSFT   0.486065  0.485725  0.525645  1.000000

# %%
import plotly.express as px

# %%
fig = px.imshow(returns.corr(),
                x=adj_close.columns,
                y=adj_close.columns,
                color_continuous_scale=list(
                    reversed(px.colors.sequential.RdBu)),
                zmin=-1, zmax=1)
fig.show()

# %% [markdown]
# ## Resampling

# %%
end_of_month = adj_close.resample("M").last()
end_of_month.head(20)
# Out:
#                 AAPL       AMZN       GOOGL       MSFT
# Date
# 2004-08-31  2.132708  38.139999   51.236237  17.673630
# 2004-09-30  2.396127  40.860001   64.864868  17.900215
# 2004-10-31  3.240182  34.130001   95.415413  18.107374
# 2004-11-30  4.146072  39.680000   91.081078  19.344421
# 2004-12-31  3.982207  44.290001   96.491493  19.279480
# 2005-01-31  4.755152  43.220001   97.907906  18.962008
# 2005-02-28  5.547884  35.180000   94.089088  18.209888
# 2005-03-31  5.153373  34.270000   90.345345  17.493368
# 2005-04-30  4.459579  32.360001  110.110107  18.311220
# 2005-05-31  4.917161  35.509998  138.773773  18.732344
# 2005-06-30  4.552333  33.090000  147.222229  18.035316
# 2005-07-31  5.274571  45.150002  144.024017  18.594385
# 2005-08-31  5.798935  42.700001  143.143143  19.938471
# 2005-09-30  6.630004  45.299999  158.388382  18.736923
# 2005-10-31  7.122217  39.860001  186.256256  18.715080
# 2005-11-30  8.387371  48.459999  202.657654  20.216032
# 2005-12-31  8.890713  47.150002  207.637634  19.098595
# 2006-01-31  9.338403  44.820000  216.546539  20.559288
# 2006-02-28  8.470230  37.439999  181.491486  19.690948
# 2006-03-31  7.756649  36.529999  195.195190  19.940111

# %%
end_of_month.resample("D").asfreq().head()  # No transformation
# Out:
#                 AAPL       AMZN      GOOGL      MSFT
# Date
# 2004-08-31  2.132708  38.139999  51.236237  17.67363
# 2004-09-01       NaN        NaN        NaN       NaN
# 2004-09-02       NaN        NaN        NaN       NaN
# 2004-09-03       NaN        NaN        NaN       NaN
# 2004-09-04       NaN        NaN        NaN       NaN

# %%
end_of_month.resample("W-FRI").ffill().head(20)  # Forward fill
# Out:
#                 AAPL       AMZN      GOOGL       MSFT
# Date
# 2004-09-03  2.132708  38.139999  51.236237  17.673630
# 2004-09-10  2.132708  38.139999  51.236237  17.673630
# 2004-09-17  2.132708  38.139999  51.236237  17.673630
# 2004-09-24  2.132708  38.139999  51.236237  17.673630
# 2004-10-01  2.396127  40.860001  64.864868  17.900215
# 2004-10-08  2.396127  40.860001  64.864868  17.900215
# 2004-10-15  2.396127  40.860001  64.864868  17.900215
# 2004-10-22  2.396127  40.860001  64.864868  17.900215
# 2004-10-29  2.396127  40.860001  64.864868  17.900215
# 2004-11-05  3.240182  34.130001  95.415413  18.107374
# 2004-11-12  3.240182  34.130001  95.415413  18.107374
# 2004-11-19  3.240182  34.130001  95.415413  18.107374
# 2004-11-26  3.240182  34.130001  95.415413  18.107374
# 2004-12-03  4.146072  39.680000  91.081078  19.344421
# 2004-12-10  4.146072  39.680000  91.081078  19.344421
# 2004-12-17  4.146072  39.680000  91.081078  19.344421
# 2004-12-24  4.146072  39.680000  91.081078  19.344421
# 2004-12-31  3.982207  44.290001  96.491493  19.279480
# 2005-01-07  3.982207  44.290001  96.491493  19.279480
# 2005-01-14  3.982207  44.290001  96.491493  19.279480

# %% [markdown]
# ## Rolling Windows

# %%
# Plot the moving average for MSFT with data from 2019
msft19 = msft.loc["2021", ["Adj Close"]].copy()

# Add the 25 day moving average as a new column to the DataFrame
msft19.loc[:, "25day average"] = msft19["Adj Close"].rolling(25).mean()
msft19.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:650, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py?line=648'>649</a> try:
# --> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py?line=649'>650</a>     return self._partial_date_slice(reso, parsed)
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py?line=650'>651</a> except KeyError as err:
#
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py:271, in DatetimeIndexOpsMixin._partial_date_slice(self, reso, parsed)
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py?line=266'>267</a> if len(self) and (
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py?line=267'>268</a>     (t1 < self[0] and t2 < self[0]) or (t1 > self[-1] and t2 > self[-1])
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py?line=268'>269</a> ):
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py?line=269'>270</a>     # we are out of range
# --> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py?line=270'>271</a>     raise KeyError
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py?line=272'>273</a> # TODO: does this depend on being monotonic _increasing_?
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py?line=273'>274</a>
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py?line=274'>275</a> # a monotonic (sorted) series can be sliced
#
# KeyError:
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/arno/Coding/python-for-excel/ch06.ipynb Cell 47' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/arno/Coding/python-for-excel/ch06.ipynb#ch0000043?line=0'>1</a> # Plot the moving average for MSFT with data from 2019
# ----> <a href='vscode-notebook-cell:/Users/arno/Coding/python-for-excel/ch06.ipynb#ch0000043?line=1'>2</a> msft19 = msft.loc["2021", ["Adj Close"]].copy()
#       <a href='vscode-notebook-cell:/Users/arno/Coding/python-for-excel/ch06.ipynb#ch0000043?line=3'>4</a> # Add the 25 day moving average as a new column to the DataFrame
#       <a href='vscode-notebook-cell:/Users/arno/Coding/python-for-excel/ch06.ipynb#ch0000043?line=4'>5</a> msft19.loc[:, "25day average"] = msft19["Adj Close"].rolling(25).mean()
#
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=958'>959</a>     if self._is_scalar_access(key):
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=959'>960</a>         return self.obj._get_value(*key, takeable=self._takeable)
# --> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=960'>961</a>     return self._getitem_tuple(key)
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=961'>962</a> else:
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=962'>963</a>     # we by definition only have the 0th axis
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=963'>964</a>     axis = self.axis or 0
#
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py:1140, in _LocIndexer._getitem_tuple(self, tup)
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1137'>1138</a> with suppress(IndexingError):
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1138'>1139</a>     tup = self._expand_ellipsis(tup)
# -> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1139'>1140</a>     return self._getitem_lowerdim(tup)
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1141'>1142</a> # no multi-index, so validate all of the indexers
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1142'>1143</a> tup = self._validate_tuple_indexer(tup)
#
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py:867, in _LocationIndexer._getitem_lowerdim(self, tup)
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=862'>863</a> for i, key in enumerate(tup):
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=863'>864</a>     if is_label_like(key):
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=864'>865</a>         # We don't need to check for tuples here because those are
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=865'>866</a>         #  caught by the _is_nested_tuple_indexer check above.
# --> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=866'>867</a>         section = self._getitem_axis(key, axis=i)
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=868'>869</a>         # We should never have a scalar section here, because
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=869'>870</a>         #  _getitem_lowerdim is only called after a check for
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=870'>871</a>         #  is_scalar_access, which that would be.
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=871'>872</a>         if section.ndim == self.ndim:
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=872'>873</a>             # we're in the middle of slicing through a MultiIndex
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=873'>874</a>             # revise the key wrt to `section` by inserting an _NS
#
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1199'>1200</a> # fall thru to straight lookup
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1200'>1201</a> self._validate_key(key, axis)
# -> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1201'>1202</a> return self._get_label(key, axis=axis)
#
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1150'>1151</a> def _get_label(self, label, axis: int):
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1151'>1152</a>     # GH#5667 this will fail if the label is not present in the axis.
# -> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexing.py?line=1152'>1153</a>     return self.obj.xs(label, axis=axis)
#
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/generic.py:3864, in NDFrame.xs(self, key, axis, level, drop_level)
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/generic.py?line=3861'>3862</a>             new_index = index[loc]
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/generic.py?line=3862'>3863</a> else:
# -> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/generic.py?line=3863'>3864</a>     loc = index.get_loc(key)
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/generic.py?line=3865'>3866</a>     if isinstance(loc, np.ndarray):
#    <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/generic.py?line=3866'>3867</a>         if loc.dtype == np.bool_:
#
# File ~/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:653, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py?line=650'>651</a>     except KeyError as err:
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py?line=651'>652</a>         if method is None:
# --> <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py?line=652'>653</a>             raise KeyError(key) from err
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py?line=653'>654</a> try:
#     <a href='file:///Users/arno/Coding/excellling/.venvexcelling/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py?line=654'>655</a>     key = self._maybe_cast_for_get_loc(key)
#
# KeyError: '2021'
